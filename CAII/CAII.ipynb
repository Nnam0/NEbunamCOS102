# %%
import tkinter as tk
from tkinter import simpledialog

# Initialize the main Tkinter window
root = tk.Tk()
root.title("PAU Cafe")
root.geometry("650x900")

# Function to handle user orders
def add_to_order():
    user_input = simpledialog.askstring("Input Required", "Please input the item and quantity").lower()
    if user_input:
        item_name, quantity = user_input.split(" ")
        if item_name not in food_prices:
            print("This item does not exist")
            return
        item_price = food_prices[item_name]
        global total_price
        total_price += item_price * int(quantity)
        total_label.config(text=f"Total: ₦{total_price}")
        ordered_items.append(item_name)
        ordered_items_prices.append(item_price * int(quantity))

def show_order_summary():
    order_summary_window = tk.Toplevel()
    order_summary_window.title("Order Summary")
    order_summary_window.geometry("600x600")

    summary_label = tk.Label(order_summary_window, text="Order Summary")
    summary_label.pack()

    customer_name_label = tk.Label(order_summary_window, text=f"Customer Name: {customer_name}")
    customer_name_label.pack()

    order_frame = tk.Frame(order_summary_window, width="250", height="500", borderwidth="2")
    order_frame.pack()

    for i in range(len(ordered_items)):
        order_item_label = tk.Label(order_frame, text=f"You ordered ₦{ordered_items_prices[i]} worth of {ordered_items[i]}")
        order_item_label.pack()

    discount, new_price = calculate_discount(total_price)
    discount_label = tk.Label(order_summary_window, text=f"You have a discount of {discount}%. Your new price is {new_price}")
    discount_label.pack()

def calculate_discount(price):
    if 1000 < price < 2500:
        discount = 10
    elif 2500 <= price < 5000:
        discount = 15
    elif price >= 5000:
        discount = 25
    else:
        discount = 0
    new_price = price - (discount / 100 * price)
    return discount, new_price

# Variables
food_prices = {
    "jollof_rice": 350,
    "cocoanut_fried_rice": 350,
    "jollof_spaghetti": 350,
    "sweet_chilli_chicken": 900,
    "grilled_chicken": 400,
    "fried_beef": 400,
    "fried_fish": 500,
    "boiled_egg": 200,
    "sausages": 200,
    "savoury_beans": 350,
    "roasted_sweet_potatoes": 300,
    "fried_plantains": 150,
    "mixed_vegetable_salad": 150,
    "boiled_yam": 150,
    "eba": 300,
    "poundo_yam": 100,
    "semo": 100,
    "acama_soup": 450,
    "egusi_soup": 450,
    "water": 200,
    "glass_drink": 150,
    "pet_drink_35cl": 300,
    "pet_drink_50cl": 350,
    "glass/canned_malt": 500,
    "fresh_yo": 600,
    "pineapple_juice": 350,
    "mango_juice": 350,
    "zobo": 350,
}

total_price = 0
ordered_items = []
ordered_items_prices = []
customer_name = simpledialog.askstring("Input Required", "Please enter your name")

# UI Components
welcome_label = tk.Label(root, text="Welcome to the PAU Cafeteria, what would you like to have today\n")
welcome_label.grid(row=0, column=0, columnspan=2, pady=(10, 10), sticky='w')

menu_label = tk.Label(root, text="This is our menu for today")
menu_label.grid(row=1, column=0, columnspan=2, pady=(0, 5), sticky='w')

# Creating sections in the grid layout
# Rice and Pasta Section
rice_pasta_label = tk.Label(root, text="Rice and Pasta")
rice_pasta_label.grid(row=2, column=0, sticky='w')
rice_pasta_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
rice_pasta_frame.grid(row=3, column=0, sticky='w')
jollof = tk.Label(rice_pasta_frame, text="Jollof Rice: ₦350")
jollof.pack()
cocoanut_fried = tk.Label(rice_pasta_frame, text="Coconut Fried Rice: ₦350")
cocoanut_fried.pack()
jollof_spaghetti = tk.Label(rice_pasta_frame, text="Jollof Spaghetti: ₦350")
jollof_spaghetti.pack()

# Proteins Section
proteins_label = tk.Label(root, text="Proteins")
proteins_label.grid(row=2, column=1, sticky='w')
proteins_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
proteins_frame.grid(row=3, column=1, sticky='w')
sweet_chilli_chicken = tk.Label(proteins_frame, text="Sweet Chilli Chicken: ₦900")
sweet_chilli_chicken.pack()
grilled_chicken = tk.Label(proteins_frame, text="Grilled Chicken: ₦400")
grilled_chicken.pack()
fried_beef = tk.Label(proteins_frame, text="Fried Beef: ₦400")
fried_beef.pack()
fried_fish = tk.Label(proteins_frame, text="Fried Fish: ₦500")
fried_fish.pack()
boiled_egg = tk.Label(proteins_frame, text="Boiled Egg: ₦200")
boiled_egg.pack()
sausages = tk.Label(proteins_frame, text="Sausages: ₦200")
sausages.pack()

# Side Dishes Section
side_dishes_label = tk.Label(root, text="Side Dishes")
side_dishes_label.grid(row=4, column=0, sticky='w')
side_dishes_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
side_dishes_frame.grid(row=5, column=0, sticky='w')
savoury_beans = tk.Label(side_dishes_frame, text="Savoury Beans: ₦350")
savoury_beans.pack()
roasted_sweet_potatoes = tk.Label(side_dishes_frame, text="Roasted Sweet Potatoes: ₦300")
roasted_sweet_potatoes.pack()
fried_plantains = tk.Label(side_dishes_frame, text="Fried Plantains: ₦150")
fried_plantains.pack()
vegetables = tk.Label(side_dishes_frame, text="Mixed Vegetable Salad: ₦150")
vegetables.pack()
yam = tk.Label(side_dishes_frame, text="Boiled Yam: ₦150")
yam.pack()

# Soups and Swallows Section
soups_and_swallows_label = tk.Label(root, text="Soups and Swallows")
soups_and_swallows_label.grid(row=4, column=1, sticky='w')
soups_and_swallows_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
soups_and_swallows_frame.grid(row=5, column=1, sticky='w')
eba = tk.Label(soups_and_swallows_frame, text="Eba: ₦300")
eba.pack()
poundo_yam = tk.Label(soups_and_swallows_frame, text="Poundo Yam: ₦100")
poundo_yam.pack()
semo = tk.Label(soups_and_swallows_frame, text="Semo: ₦100")
semo.pack()
acama = tk.Label(soups_and_swallows_frame, text="Acama Soup: ₦450")
acama.pack()
egusi = tk.Label(soups_and_swallows_frame, text="Egusi Soup: ₦450")
egusi.pack()

# Beverages Section
beverages_label = tk.Label(root, text="Beverages")
beverages_label.grid(row=6, column=0, sticky='w')
beverages_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
beverages_frame.grid(row=7, column=0, columnspan=2, sticky='w')
water = tk.Label(beverages_frame, text="Water: ₦200")
water.pack()
glass_drink = tk.Label(beverages_frame, text="Glass Drink: ₦150")
glass_drink.pack()
pet_drink_35cl = tk.Label(beverages_frame, text="Pet Drink 35cl: ₦300")
pet_drink_35cl.pack()
pet_drink_50cl = tk.Label(beverages_frame, text="Pet Drink 50cl: ₦350")
pet_drink_50cl.pack()
malt = tk.Label(beverages_frame, text="Glass/Canned Malt: ₦500")
malt.pack()
fresh_yo = tk.Label(beverages_frame, text="Fresh Yo: ₦600")
fresh_yo.pack()
pineapple_juice = tk.Label(beverages_frame, text="Pineapple Juice: ₦350")
pineapple_juice.pack()
mango_juice = tk.Label(beverages_frame, text="Mango Juice: ₦350")
mango_juice.pack()
zobo = tk.Label(beverages_frame, text="Zobo: ₦350")
zobo.pack()


for section_name, row, column in menu_sections:
    section_label = tk.Label(root, text=section_name)
    section_label.grid(row=row, column=column, sticky='w')

    section_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
    section_frame.grid(row=row + 1, column=column, sticky='w')

    for item_name, price in food_prices.items():
        if section_name.lower() in item_name:
            item_label = tk.Label(section_frame, text=f"{item_name.capitalize()}: ₦{price}")
            item_label.pack()

total_label = tk.Label(root, text=f"Total: ₦{total_price}")
total_label.grid(row=7, column=0, columnspan=2, sticky="w")

# Buttons
place_order_button = tk.Button(root, text="Add item", command=add_to_order)
place_order_button.grid(row=8, column=0, columnspan=2, pady=10, sticky='w')

submit_order_button = tk.Button(root, text="Finalize Order", command=show_order_summary)
submit_order_button.grid(row=8, column=1, sticky="w")

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 190
#     186 zobo = tk.Label(beverages_frame, text="Zobo: ₦350")
#     187 zobo.pack()
# --> 190 for section_name, row, column in menu_sections:
#     191     section_label = tk.Label(root, text=section_name)
#     192     section_label.grid(row=row, column=column, sticky='w')
#
# NameError: name 'menu_sections' is not defined

# %%
#1. Start
#2. Initialize tkinter window
#3. Define function add_to_order():
   #a. Ask user to input their name
   #b. Ask user to input item name and quantity
   #c. Validate input and calculate total price
   #d. Add ordered item to list
#4. Define function show_order_summary():
   #a. Display order summary window
   #b. Display customer name
   #c. Calculate discount and new price
   #d. Display ordered items and prices
   #e. Display discount and new price
#5. Define function calculate_discount(price):
   #a. Calculate discount based on price
   #b. Calculate new price after discount
   #c. Return discount and new price
#6. Define menu sections and food prices
#7. Create UI components:
   #a. Labels for welcome message, menu, and total price
   #b. Buttons for placing and submitting orders
#8. Display UI components in tkinter window
#9. Start tkinter event loop
#10. End

# %%
import tkinter as tk
from tkinter import simpledialog

# Initialize the main Tkinter window
root = tk.Tk()
root.title("PAU Cafe")
root.geometry("650x900")

# Function to handle user orders
def add_to_order():
    user_input = simpledialog.askstring("Input Required", "Please input the item and quantity").lower()
    if user_input:
        item_name, quantity = user_input.split(" ")
        if item_name not in food_prices:
            print("This item does not exist")
            return
        item_price = food_prices[item_name]
        global total_price
        total_price += item_price * int(quantity)
        total_label.config(text=f"Total: ₦{total_price}")
        ordered_items.append(item_name)
        ordered_items_prices.append(item_price * int(quantity))

def show_order_summary():
    order_summary_window = tk.Toplevel()
    order_summary_window.title("Order Summary")
    order_summary_window.geometry("600x600")

    summary_label = tk.Label(order_summary_window, text="Order Summary")
    summary_label.pack()

    customer_name_label = tk.Label(order_summary_window, text=f"Customer Name: {customer_name}")
    customer_name_label.pack()

    order_frame = tk.Frame(order_summary_window, width="250", height="500", borderwidth="2")
    order_frame.pack()

    for i in range(len(ordered_items)):
        order_item_label = tk.Label(order_frame, text=f"You ordered ₦{ordered_items_prices[i]} worth of {ordered_items[i]}")
        order_item_label.pack()

    discount, new_price = calculate_discount(total_price)
    discount_label = tk.Label(order_summary_window, text=f"You have a discount of {discount}%. Your new price is {new_price}")
    discount_label.pack()

def calculate_discount(price):
    if 1000 < price < 2500:
        discount = 10
    elif 2500 <= price < 5000:
        discount = 15
    elif price >= 5000:
        discount = 25
    else:
        discount = 0
    new_price = price - (discount / 100 * price)
    return discount, new_price

# Variables
food_prices = {
    "jollof_rice": 350,
    "cocoanut_fried_rice": 350,
    "jollof_spaghetti": 350,
    "sweet_chilli_chicken": 900,
    "grilled_chicken": 400,
    "fried_beef": 400,
    "fried_fish": 500,
    "boiled_egg": 200,
    "sausages": 200,
    "savoury_beans": 350,
    "roasted_sweet_potatoes": 300,
    "fried_plantains": 150,
    "mixed_vegetable_salad": 150,
    "boiled_yam": 150,
    "eba": 300,
    "poundo_yam": 100,
    "semo": 100,
    "acama_soup": 450,
    "egusi_soup": 450,
    "water": 200,
    "glass_drink": 150,
    "pet_drink_35cl": 300,
    "pet_drink_50cl": 350,
    "glass/canned_malt": 500,
    "fresh_yo": 600,
    "pineapple_juice": 350,
    "mango_juice": 350,
    "zobo": 350,
}

total_price = 0
ordered_items = []
ordered_items_prices = []
customer_name = simpledialog.askstring("Input Required", "Please enter your name")

# UI Components
welcome_label = tk.Label(root, text="Welcome to the PAU Cafeteria, what would you like to have today\n")
welcome_label.grid(row=0, column=0, columnspan=2, pady=(10, 10), sticky='w')

menu_label = tk.Label(root, text="This is our menu for today")
menu_label.grid(row=1, column=0, columnspan=2, pady=(0, 5), sticky='w')

# Creating sections in the grid layout
# Rice and Pasta Section
rice_pasta_label = tk.Label(root, text="Rice and Pasta")
rice_pasta_label.grid(row=2, column=0, sticky='w')
rice_pasta_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
rice_pasta_frame.grid(row=3, column=0, sticky='w')
jollof = tk.Label(rice_pasta_frame, text="Jollof Rice: ₦350")
jollof.pack()
cocoanut_fried = tk.Label(rice_pasta_frame, text="Coconut Fried Rice: ₦350")
cocoanut_fried.pack()
jollof_spaghetti = tk.Label(rice_pasta_frame, text="Jollof Spaghetti: ₦350")
jollof_spaghetti.pack()

# Proteins Section
proteins_label = tk.Label(root, text="Proteins")
proteins_label.grid(row=2, column=1, sticky='w')
proteins_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
proteins_frame.grid(row=3, column=1, sticky='w')
sweet_chilli_chicken = tk.Label(proteins_frame, text="Sweet Chilli Chicken: ₦900")
sweet_chilli_chicken.pack()
grilled_chicken = tk.Label(proteins_frame, text="Grilled Chicken: ₦400")
grilled_chicken.pack()
fried_beef = tk.Label(proteins_frame, text="Fried Beef: ₦400")
fried_beef.pack()
fried_fish = tk.Label(proteins_frame, text="Fried Fish: ₦500")
fried_fish.pack()
boiled_egg = tk.Label(proteins_frame, text="Boiled Egg: ₦200")
boiled_egg.pack()
sausages = tk.Label(proteins_frame, text="Sausages: ₦200")
sausages.pack()

# Side Dishes Section
side_dishes_label = tk.Label(root, text="Side Dishes")
side_dishes_label.grid(row=4, column=0, sticky='w')
side_dishes_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
side_dishes_frame.grid(row=5, column=0, sticky='w')
savoury_beans = tk.Label(side_dishes_frame, text="Savoury Beans: ₦350")
savoury_beans.pack()
roasted_sweet_potatoes = tk.Label(side_dishes_frame, text="Roasted Sweet Potatoes: ₦300")
roasted_sweet_potatoes.pack()
fried_plantains = tk.Label(side_dishes_frame, text="Fried Plantains: ₦150")
fried_plantains.pack()
vegetables = tk.Label(side_dishes_frame, text="Mixed Vegetable Salad: ₦150")
vegetables.pack()
yam = tk.Label(side_dishes_frame, text="Boiled Yam: ₦150")
yam.pack()

# Soups and Swallows Section
soups_and_swallows_label = tk.Label(root, text="Soups and Swallows")
soups_and_swallows_label.grid(row=4, column=1, sticky='w')
soups_and_swallows_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
soups_and_swallows_frame.grid(row=5, column=1, sticky='w')
eba = tk.Label(soups_and_swallows_frame, text="Eba: ₦300")
eba.pack()
poundo_yam = tk.Label(soups_and_swallows_frame, text="Poundo Yam: ₦100")
poundo_yam.pack()
semo = tk.Label(soups_and_swallows_frame, text="Semo: ₦100")
semo.pack()
acama = tk.Label(soups_and_swallows_frame, text="Acama Soup: ₦450")
acama.pack()
egusi = tk.Label(soups_and_swallows_frame, text="Egusi Soup: ₦450")
egusi.pack()

# Beverages Section
beverages_label = tk.Label(root, text="Beverages")
beverages_label.grid(row=6, column=0, sticky='w')
beverages_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
beverages_frame.grid(row=7, column=0, columnspan=2, sticky='w')
water = tk.Label(beverages_frame, text="Water: ₦200")
water.pack()
glass_drink = tk.Label(beverages_frame, text="Glass Drink: ₦150")
glass_drink.pack()
pet_drink_35cl = tk.Label(beverages_frame, text="Pet Drink 35cl: ₦300")
pet_drink_35cl.pack()
pet_drink_50cl = tk.Label(beverages_frame, text="Pet Drink 50cl: ₦350")
pet_drink_50cl.pack()
malt = tk.Label(beverages_frame, text="Glass/Canned Malt: ₦500")
malt.pack()
fresh_yo = tk.Label(beverages_frame, text="Fresh Yo: ₦600")
fresh_yo.pack()
pineapple_juice = tk.Label(beverages_frame, text="Pineapple Juice: ₦350")
pineapple_juice.pack()
mango_juice = tk.Label(beverages_frame, text="Mango Juice: ₦350")
mango_juice.pack()
zobo = tk.Label(beverages_frame, text="Zobo: ₦350")
zobo.pack()


for section_name, row, column in menu_sections:
    section_label = tk.Label(root, text=section_name)
    section_label.grid(row=row, column=column, sticky='w')

    section_frame = tk.Frame(root, borderwidth=2, padx=10, pady=10)
    section_frame.grid(row=row + 1, column=column, sticky='w')

    for item_name, price in food_prices.items():
        if section_name.lower() in item_name:
            item_label = tk.Label(section_frame, text=f"{item_name.capitalize()}: ₦{price}")
            item_label.pack()

total_label = tk.Label(root, text=f"Total: ₦{total_price}")
total_label.grid(row=7, column=0, columnspan=2, sticky="w")

# Buttons
place_order_button = tk.Button(root, text="Add item", command=add_to_order)
place_order_button.grid(row=8, column=0, columnspan=2, pady=10, sticky='w')

submit_order_button = tk.Button(root, text="Finalize Order", command=show_order_summary)
submit_order_button.grid(row=8, column=1, sticky="w")

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 190
#     186 zobo = tk.Label(beverages_frame, text="Zobo: ₦350")
#     187 zobo.pack()
# --> 190 for section_name, row, column in menu_sections:
#     191     section_label = tk.Label(root, text=section_name)
#     192     section_label.grid(row=row, column=column, sticky='w')
#
# NameError: name 'menu_sections' is not defined
